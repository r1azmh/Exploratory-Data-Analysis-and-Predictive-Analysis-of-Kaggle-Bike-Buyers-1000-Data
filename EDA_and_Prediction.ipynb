# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Import Important Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import warnings
import ipywidgets
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Read Data

# %%
#data read
df = pd.read_csv("../input/bike-buyers/bike_buyers_clean.csv")
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Marital Status    1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Income            1000 non-null   int64
#  4   Children          1000 non-null   int64
#  5   Education         1000 non-null   object
#  6   Occupation        1000 non-null   object
#  7   Home Owner        1000 non-null   object
#  8   Cars              1000 non-null   int64
#  9   Commute Distance  1000 non-null   object
#  10  Region            1000 non-null   object
#  11  Age               1000 non-null   int64
#  12  Purchased Bike    1000 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 101.7+ KB
# None
#       ID Marital Status  Gender  Income  Children        Education  \
# 0  12496        Married  Female   40000         1        Bachelors
# 1  24107        Married    Male   30000         3  Partial College
# 2  14177        Married    Male   80000         5  Partial College
# 3  24381         Single    Male   70000         0        Bachelors
# 4  25597         Single    Male   30000         0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# 1        Clerical        Yes     1        0-1 Miles   Europe   43
# 2    Professional         No     2        2-5 Miles   Europe   60
# 3    Professional        Yes     1       5-10 Miles  Pacific   41
# 4        Clerical         No     0        0-1 Miles   Europe   36
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %% [markdown]
# ### Data Count

# %%
#data count
print("-------------------------------")
print(df["Purchased Bike"].value_counts())
print("-------------------------------")
# Out:
# -------------------------------
# No     519
# Yes    481
# Name: Purchased Bike, dtype: int64
# -------------------------------

# %% [markdown]
# ### Bike Purchase Trend According to Gender

# %%
#Bike purchasing trend accoreding to gender
#plot data
fig, ax=plt.subplots(figsize=(9, 11))
ax=sns.countplot(x="Purchased Bike", data=df, hue='Gender', hue_order=['Male', 'Female'])

#Setting labels and font size
ax.set(xlabel='Purchased Bike', ylabel='Count of No/Yes',title="Count of People who Purchased the Bike and who Did't")
ax.xaxis.get_label().set_fontsize(10)
ax.yaxis.get_label().set_fontsize(10)

plt.show()

# %% [markdown]
# ### Bike Purchasing Trend According to Region

# %%
#Bike purchasing trend accoreding to region
fig, ax=plt.subplots(figsize=(9, 6))
ax=sns.countplot(x="Purchased Bike", data=df, hue='Region')

#Setting labels and font size
ax.set(xlabel='Purchased Bike', ylabel='Count of No/Yes',title="Count of People who Purchased the Bike and who Did't")
ax.xaxis.get_label().set_fontsize(14)
ax.yaxis.get_label().set_fontsize(14)

plt.show()

# %% [markdown]
# ### Bike Purchasing Trend According Occupation

# %%
#Bike purchasing trend accoreding to occupation
fig, ax=plt.subplots(figsize=(9, 6))
ax=sns.countplot(x="Purchased Bike", data=df, hue='Occupation', hue_order=['Professional', 'Skilled Manual', 'Clerical', 'Management', 'Manual'])

#Setting labels and font size
ax.set(xlabel='Purchased Bike', ylabel='Count of No/Yes',title="Count of People who Purchased the Bike and who Did't")
ax.xaxis.get_label().set_fontsize(14)
ax.yaxis.get_label().set_fontsize(14)

plt.show()

# %% [markdown]
# ### Bike Purchasing Trend According to Age

# %%
#Bike Purchasing Trend According to Age
sns.histplot(x="Age", data=df, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[20, 30, 40, 50, 60, 70, 80, 90], palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ### Bike Purchasing Trend According to Marital Status

# %%
#Bike Purchasing Trend According to Marital Status
sns.histplot(x="Marital Status", data=df, hue="Purchased Bike", multiple="dodge", shrink=0.4, palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ### Bike Purchasing Trend According to Salary

# %%
#Bike Purchasing Trend According to Salary
sns.histplot(x="Income", data=df, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[10000, 25000, 40000, 55000, 70000, 85000, 100000, 115000, 130000, 145000, 160000, 175000, 190000, 205000], palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ### Bike Purchasing Trend According to Education

# %%
#Bike Purchasing Trend According to Education
fig, ax=plt.subplots(figsize=(11, 6))
sns.set_theme(style='white', palette=None)
sns.histplot(x="Education", data=df, hue="Purchased Bike", multiple="dodge", shrink=0.6, palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ### Bike Purchasing Trend According to Numbers of their Children

# %%
#Bike Purchasing Trend According to Numbers of their Children
sns.histplot(x="Children", data=df, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[0, 1, 2, 3, 4, 5, 6], palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ### Bike Purchasing Trend According to Number of Cars They Own

# %%
#Bike Purchasing Trend According to Number of Cars They Own
sns.histplot(x="Cars", data=df, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[0, 1, 2, 3, 4, 5], palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ### Bike Purchasing Trend of Home Owners

# %%
#Bike Purchasing Trend of Home Owners
sns.histplot(x="Home Owner", data=df, hue="Purchased Bike", multiple="dodge", shrink=0.2, palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ### Bike Purchasing Trend According to Commuting Distance

# %%
#Bike Purchasing Trend According to Commuting Distance
sns.histplot(x="Commute Distance", data=df, hue="Purchased Bike", multiple="dodge", shrink=0.8, bins=[0, 1, 2, 3, 4, 5, 6], palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ### Scatter Plots

# %%
#Scatter plot Cars vs Age
sns.scatterplot(x="Cars", y="Age", data=df, hue="Purchased Bike", palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %%
#Scatter plot Income vs Age
fig, ax=plt.subplots(figsize=(9, 6))
sns.scatterplot(x="Income", y="Age", data=df, hue="Purchased Bike", palette=sns.blend_palette(['red', 'green'], 2))
plt.show()

# %% [markdown]
# ### Density Plots

# %%
#Pair Plot Income vs Age
sns.pairplot(df, vars=["Income", "Age"], hue="Purchased Bike", kind="reg", palette=sns.blend_palette(['red', 'green'], 2))

# %%
from ipywidgets import interactive
def size(height=3.5, aspect=1.5):
    sns.pairplot(df, vars=["Income", "Age"], hue="Purchased Bike", kind="reg", palette=sns.blend_palette(['red', 'green'], 2), height=height, aspect=aspect)

# %%
interactive(size, height=(1, 5, 0.5), aspect=(0.5, 3, 0.25))
# Out:
# interactive(children=(FloatSlider(value=3.5, description='height', max=5.0, min=1.0, step=0.5), FloatSlider(va…

# %% [markdown]
# # Prediction Using Random Forest Classifier

# %% [markdown]
# ### Import Important Libraries

# %%
#Libraries for Prediction
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %% [markdown]
# ### Feature Engineering

# %%
df.dtypes
# Out:
# ID                   int64
# Marital Status      object
# Gender              object
# Income               int64
# Children             int64
# Education           object
# Occupation          object
# Home Owner          object
# Cars                 int64
# Commute Distance    object
# Region              object
# Age                  int64
# Purchased Bike      object
# dtype: object

# %% [markdown]
# ### Change Objects into Categorical Data

# %%
# Change object types into categorical
df['Education'] = pd.Categorical(df['Education'])
df['Occupation'] = pd.Categorical(df['Occupation'])
df['Commute Distance'] = pd.Categorical(df['Commute Distance'])
df['Region'] = pd.Categorical(df['Region'])
df['Gender'] = pd.Categorical(df['Gender'])
df['Home Owner'] = pd.Categorical(df['Home Owner'])
df['Marital Status'] = pd.Categorical(df['Marital Status'])

# %%
# Change purchased bike value into int
df['Purchased Bike'] = df['Purchased Bike'].map({'Yes' : 1, 'No' : 0})

# %%
df.dtypes
# Out:
# ID                     int64
# Marital Status      category
# Gender              category
# Income                 int64
# Children               int64
# Education           category
# Occupation          category
# Home Owner          category
# Cars                   int64
# Commute Distance    category
# Region              category
# Age                    int64
# Purchased Bike         int64
# dtype: object

# %% [markdown]
# ### Transform Categorical Features into Dummy Variables

# %%
# Tansform categorical feature into dummy variables
df = pd.get_dummies(df, drop_first= True)

# %% [markdown]
# ### Droping Irrelevant Data

# %%
#Droping Irrelevant Data
df.drop('ID', axis = 1, inplace = True)

# %%
df.head(5)
# Out:
#    Income  Children  Cars  Age  Purchased Bike  Marital Status_Single  \
# 0   40000         1     0   42               0                      0
# 1   30000         3     1   43               0                      0
# 2   80000         5     2   60               0                      0
# 3   70000         0     1   41               1                      1
# 4   30000         0     0   36               1                      1
#
#    Gender_Male  Education_Graduate Degree  Education_High School  \
# 0            0                          0                      0
# 1            1                          0                      0
# 2            1                          0                      0
# 3            1                          0                      0
# 4            1                          0                      0
#
#    Education_Partial College  ...  Occupation_Manual  Occupation_Professional  \
# 0                          0  ...                  0                        0
# 1                          1  ...                  0                        0
# 2                          1  ...                  0                        1
# 3                          0  ...                  0                        1
# 4                          0  ...                  0                        0
#
#    Occupation_Skilled Manual  Home Owner_Yes  Commute Distance_1-2 Miles  \
# 0                          1               1                           0
# 1                          0               1                           0
# 2                          0               0                           0
# 3                          0               1                           0
# 4                          0               0                           0
#
#    Commute Distance_10+ Miles  Commute Distance_2-5 Miles  \
# 0                           0                           0
# 1                           0                           0
# 2                           0                           1
# 3                           0                           0
# 4                           0                           0
#
#    Commute Distance_5-10 Miles  Region_North America  Region_Pacific
# 0                            0                     0               0
# 1                            0                     0               0
# 2                            0                     0               0
# 3                            1                     0               1
# 4                            0                     0               0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Defining Dependent and Independent Variables

# %%
#Defining Dependent and Independent Variables
X=df.drop(['Purchased Bike'], axis=1)
y=df['Purchased Bike']

# %% [markdown]
# ### Split Data

# %%
#Split data
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.30)

# %% [markdown]
# ### Training the Model

# %%
#Training the model
model = RandomForestClassifier(n_estimators=100, max_depth=20, random_state=0)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, random_state=0)

# %% [markdown]
# ### Accuracy

# %%
#Printing accuracy of the model
score1 = model.score(X_train, y_train)
score2 = model.score(X_test, y_test)


print("Training set accuracy: ", '%.3f'%(score1))
print("Test set accuracy: ", '%.3f'%(score2))
# Out:
# Training set accuracy:  0.996
# Test set accuracy:  0.727

# %% [markdown]
# ### Comparing Test Data vs Predicted Data

# %%
#Comparing Test Data vs Predicted Data
i=0
y_pred=model.predict(X_test)
test_result=list(y_test)
#for i in range(len(y_test)):
for i in range(10):
    print('-----------------------')
    print('Case:', i+1)
    print(y_pred[i])
    print(test_result[i])
    if y_pred[i]==test_result[i]:
        print('Prediction is correct')
    else:
        print('Prediction is incorrect')
# Out:
# -----------------------
# Case: 1
# 0
# 0
# Prediction is correct
# -----------------------
# Case: 2
# 1
# 0
# Prediction is incorrect
# -----------------------
# Case: 3
# 0
# 1
# Prediction is incorrect
# -----------------------
# Case: 4
# 0
# 0
# Prediction is correct
# -----------------------
# Case: 5
# 0
# 1
# Prediction is incorrect
# -----------------------
# Case: 6
# 0
# 1
# Prediction is incorrect
# -----------------------
# Case: 7
# 0
# 0
# Prediction is correct
# -----------------------
# Case: 8
# 1
# 1
# Prediction is correct
# -----------------------
# Case: 9
# 0
# 1
# Prediction is incorrect
# -----------------------
# Case: 10
# 1
# 1
# Prediction is correct

# %% [markdown]
# ### Confusion Matrix

# %%
#Displaying confusion matrix of the model

from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)
disp=ConfusionMatrixDisplay(confusion_matrix=cm)

disp.plot()
plt.show()

# %% [markdown]
# ### Statistical Analysis of the Model

# %%
#Statistical Analysis
from sklearn.model_selection import cross_validate
clf = []
clf.append(RandomForestClassifier())

classifier_name = []
mean_value = []
std_value = []

scores = cross_validate(model, X_train, y_train)
print('---------------------------------')
print('Random Forest Classifier')
print('---------------------------------')
    
for key, values in scores.items():
        
    classifier_name.append(clf)
    mean_value.append(values.mean())
    std_value.append(values.std())
        
    print(key,' mean ', values.mean())
    print(key,' std ', values.std())
# Out:
# ---------------------------------
# Random Forest Classifier
# ---------------------------------
# fit_time  mean  0.22393569946289063
# fit_time  std  0.002202930277328612
# score_time  mean  0.012675094604492187
# score_time  std  5.6740295889697064e-05
# test_score  mean  0.7085714285714286
# test_score  std  0.022767682072156046

# %%
#from sklearn.metrics import classification_report
from sklearn.metrics import classification_report
# Printing classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72       150
#            1       0.72      0.74      0.73       150
#
#     accuracy                           0.73       300
#    macro avg       0.73      0.73      0.73       300
# weighted avg       0.73      0.73      0.73       300
